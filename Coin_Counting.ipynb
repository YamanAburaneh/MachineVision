# %%
#Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Declare path for the files
path = "/content/gdrive/MyDrive/DLIVACV_workshop/Quiz1/"

# %%
#Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image 
from IPython.display import Image
# %matplotlib inline

# %%
#Import image and covert from BGR to RGB
img_coin = cv2.imread(path+'Lira.jpg',cv2.IMREAD_COLOR)
img_coin_rgb = cv2.cvtColor(img_coin, cv2.COLOR_BGR2RGB)

plt.imshow(img_coin_rgb)

# %%
#Convert image to Grayscale 
image = cv2.imread(path+"Lira.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
#GaussianBlur is applied 
#Second parameter is the Gaussian Kernel Size
#Third parameter is the Kernel standard deviation
blur = cv2.GaussianBlur(gray, (11,11),0) 
plt.imshow(blur, cmap="gray")

# %%
#Use Canny filter to detect the edges
#Second parameters are the lower and upper value for the threshold
#3 represents the kernel size for the sobel filter which will calculating the edge
canny = cv2.Canny(blur, 30, 300, 3)
plt.imshow(canny, cmap='gray')

# %%
#Using dilation filter to connect the edges and make it thicker
dilated = cv2.dilate(canny, (1,1), iterations=2)
plt.imshow(dilated, cmap='gray')

# %%
#Calculate and find the Contours 
(cnt, heirarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

#2 represents the thickness which is the last parameter
rgb = cv2.cvtColor(img_coin1, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb, cnt, -1, (0,255,0), 2) 

plt.imshow(rgb)

# %%
#Print the number of coins in the image
print("Coins in the image: ", len(cnt))
# Out:
# Coins in the image:  6
